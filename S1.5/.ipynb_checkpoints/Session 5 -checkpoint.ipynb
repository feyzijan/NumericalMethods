# %%
# Exercise 1: Create a list of tuplets with each tuplet containg a students name, mark, and group
#Copy contents of the text files into lists

N = open('Names.txt', 'r')
M = open('Marks.txt', 'r')
G = open('Groups.txt', 'r')

# Read lines from the text files
n = N.readlines()
m = M.readlines()
g = G.readlines()

# form lists with the elements from the files
Names = []
Marks = []
Groups = []

for item in n:
    Names = Names + [item.rstrip()] # clean the string data 
    
for item in m:
    Marks = Marks + [int(item)]
    
for item in g:
    Groups = Groups + [item.rstrip()] # clean the string data


R = range(0,len(Marks))

a = []

for i in R:
   a = a + [(Names[i], Marks[i], Groups[i])]  # add elements to the list, each element being a tuplet

#print(a[20][1])
# Out:
# 79

# %%
# Exercise 2: Sort students in descending order of marks
N = len(a)

Ri= range(0,N)

for i in Rk:
    Rj = range(i+1, N)
    for j in Rj: # if the n+1th element is larger than the nth element, swap their positions 
        if a[j][1] > a[i][1]:    # compare their marks hence [1] at the end
            (a[j], a[i]) = (a[i], a[j])  # swap using tuples
         
        
#print(a[40])
# Out:
# ('Rizwan Ahmad', 76, '5b')

# %%
Rm= range(0,101)
tlist = []

for i in Rm: # repeat for each possible mark, which is between 0 and 100
    count = 0
    marknames = [] 
    Rj= range(0, len(a))
    for j in Rj:
        if i == a[j][1]:
            count = count + 1 # count the number of times the mark appears
            marknames = marknames + [a[j][0]]  # record the names of those with the mark in a list
    if count > 0: # if the mark does indeed appear
        tlist = tlist + [(i, count, marknames)] # add the mark, its occurence, and the names to the list as a tuplet
    

for item in tlist:
    print (item)

# Now to the Graphing

import matplotlib.pyplot as pl
x = []
y = []

Rg = range(0, len(tlist))

for i in Rg: # Store marks in x
    x = x + [tlist[i][0]]
    
for i in Rg: # store occurrences in y
    y = y + [tlist[i][1]]
    
print (x)
print(y)

pl.plot(x,y)
    
    
u = [(2,3,4),()]

print(u[1])
# Out:
# (1, 3, ['Yilong', 'Konrad', 'Raphael Joseph'])
# (3, 1, ['Priya Kaur'])
# (4, 3, ['Lavina Yanyeuk Patricia', 'Wern Shynn', 'Lamees'])
# (6, 2, ['Paul-Anael', 'Nikhil'])
# (7, 3, ['Syed Muhammad', 'Peter William You-Chen', 'Dharanee'])
# (8, 3, ['James Keen Hong', 'Izz Rasyad', 'Khama'])
# (9, 1, ['Siyi'])
# (10, 1, ['Vilmos'])
# (11, 2, ['Xiaoni', 'Ee Ezekiel'])
# (12, 1, ['Zachary'])
# (13, 3, ['Matei-Cristian', 'Samuel', 'Martin Jia Hao'])
# (14, 1, ['Marie'])
# (15, 3, ['Thomas', 'Michael Henry', 'Huw Silas Kenneth'])
# (16, 1, ['Kulappu Arachchige Donna Brindhiini'])
# (17, 1, ['Qi Hua'])
# (18, 1, ['Matteo Gabriel'])
# (19, 1, ['Chi Him'])
# (22, 3, ['Manith Lakvindu', 'Gaurav Girish', 'Manmohan'])
# (23, 1, ['Dimitrios'])
# (24, 1, ['Charles'])
# (25, 2, ['Karim', 'Luis'])
# (26, 5, ['Vinzenz', 'Eugene Yucheng', 'Ryan (Chun)', 'Yixuan', 'Leo'])
# (27, 3, ['Connell', 'Pierre', 'Alexander Milford'])
# (28, 1, ['Alice'])
# (30, 1, ['Victor'])
# (31, 1, ['Federico'])
# ...
